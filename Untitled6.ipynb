# %% [markdown]
# <a href="https://colab.research.google.com/github/sattipraveena/deep-learning/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
print(os.listdir('/content'))
# Out:
# ['.config', 'Sap_013 (14).jpg', 'Sap_148 (21).jpg', 'Sap_148 (68).jpg', 'Sap_148 (75).jpg', 'Sap_148 (73).jpg', 'Sap_013 (11).jpg', 'Sap_148 (63).jpg', 'Sap_148 (25).jpg', 'Sap_013 (34).jpg', 'Sap_013 (12).jpg', 'Sap_148 (90).jpg', 'Sap_148 (109).jpg', 'Sap_013 (20).jpg', 'Sap_148 (36).jpg', 'Sap_013 (17).jpg', 'Sap_148 (37).jpg', 'Sap_148 (27).jpg', 'Sap_148 (87).jpg', 'Sap_013 (23).jpg', 'Sap_013 (35).jpg', 'Sap_148 (17).jpg', 'Sap_148 (8).jpg', 'Sap_148 (20).jpg', 'Sap_148 (45).jpg', 'Sap_148 (34).jpg', 'Sap_148 (23).jpg', 'Sap_013 (30).jpg', 'Sap_148 (62).jpg', 'Sap_148 (59).jpg', 'Sap_013 (27).jpg', 'Sap_148 (80).jpg', 'Sap_148 (31).jpg', 'Sap_148 (52).jpg', 'Sap_148 (28).jpg', 'Sap_013 (44).jpg', 'Sap_013 (24).jpg', 'Sap_013 (5).jpg', 'Sap_148 (30).jpg', 'Sap_148 (69).jpg', 'Sap_148 (49).jpg', 'Sap_148 (108).jpg', 'Sap_013 (39).jpg', 'Sap_148 (84).jpg', 'Sap_013 (33).jpg', 'Sap_148 (82).jpg', 'Sap_148 (71).jpg', 'Sap_013 (41).jpg', 'Sap_148 (26).jpg', 'Sap_148 (107).jpg', 'Sap_148 (47).jpg', 'Sap_148 (104).jpg', 'Sap_013 (15).jpg', 'Sap_013 (38).jpg', 'Sap_013 (29).jpg', 'Sap_148 (10).jpg', 'Sap_013 (37).jpg', 'Sap_148 (38).jpg', 'Sap_148 (39).jpg', 'Sap_013 (21).jpg', 'Sap_148 (103).jpg', 'Sap_013 (25).jpg', 'Sap_148 (91).jpg', 'Sap_013 (9).jpg', 'Sap_148 (98).jpg', 'Sap_148 (92).jpg', 'Sap_148 (58).jpg', 'Sap_148 (7).jpg', 'Sap_148 (101).jpg', 'Sap_148 (88).jpg', 'Sap_148 (67).jpg', 'Sap_148 (40).jpg', 'Sap_148 (93).jpg', 'Sap_148 (48).jpg', 'Sap_148 (55).jpg', 'Sap_148 (1).jpg', 'Sap_148 (33).jpg', 'Sap_148 (97).jpg', 'Sap_013 (8).jpg', 'Sap_013 (43).jpg', 'Sap_148 (64).jpg', 'Sap_148 (11).jpg', 'Sap_148 (2).jpg', 'Sap_148 (70).jpg', 'Sap_148 (9).jpg', 'Sap_148 (56).jpg', 'Sap_148 (24).jpg', 'Sap_013 (36).jpg', 'Sap_148 (76).jpg', 'Sap_148 (18).jpg', 'Sap_148 (57).jpg', 'Sap_148 (102).jpg', 'Sap_013 (40).jpg', 'Sap_013 (26).jpg', 'Sap_148 (66).jpg', 'Sap_148 (96).jpg', 'Sap_148 (99).jpg', 'Sap_013 (3).jpg', 'Sap_148 (60).jpg', 'Sap_013 (7).jpg', 'Sap_013 (16).jpg', 'Sap_148 (72).jpg', 'Sap_148 (46).jpg', 'Sap_148 (19).jpg', 'Sap_148 (51).jpg', 'Sap_148 (5).jpg', 'Sap_148 (43).jpg', 'Sap_148 (95).jpg', 'Sap_148 (100).jpg', 'Sap_013 (32).jpg', 'Sap_013 (4).jpg', 'Sap_148 (4).jpg', 'Sap_013 (2).jpg', 'Sap_148 (105).jpg', 'Sap_148 (74).jpg', 'Sap_148 (35).jpg', 'Sap_013 (28).jpg', 'Sap_013 (31).jpg', 'Sap_148 (81).jpg', 'Sap_013 (19).jpg', 'Sap_148 (50).jpg', 'Sap_148 (78).jpg', 'Sap_148 (42).jpg', 'Sap_013 (18).jpg', 'Sap_148 (89).jpg', 'Sap_148 (54).jpg', 'Sap_013 (13).jpg', 'Sap_148 (83).jpg', 'Sap_148 (32).jpg', 'Sap_013 (10).jpg', 'Sap_148 (79).jpg', 'Sap_148 (3).jpg', 'Sap_148 (86).jpg', 'Sap_013 (1).jpg', 'Sap_148 (44).jpg', 'Sap_148 (61).jpg', 'Sap_148 (12).jpg', 'Sap_148 (53).jpg', 'Sap_148 (16).jpg', 'Sap_013 (42).jpg', 'Sap_148 (77).jpg', 'Sap_148 (65).jpg', 'Sap_148 (14).jpg', 'Sap_148 (22).jpg', 'Sap_148 (6).jpg', 'Sap_148 (106).jpg', 'Sap_148 (13).jpg', 'Sap_148 (41).jpg', 'Sap_148 (15).jpg', 'Sap_148 (29).jpg', 'sample_data']

# %%
import os

# Create a folder named "images" in /content
folder_path = '/content/images'
os.makedirs(folder_path, exist_ok=True)

# %%
import shutil

# List all files in /content
for file_name in os.listdir('/content'):
    # Check if it's an image file
    if file_name.endswith(('.jpg', '.png', '.jpeg', '.bmp', '.gif')):
        # Move the image to the folder
        shutil.move(f'/content/{file_name}', f'{folder_path}/{file_name}')

# %%
# List all files in the folder
print("Images in the folder:")
print(os.listdir(folder_path))
# Out:
# Images in the folder:
# ['Sn1ap_024 (60).jpg', 'Sap_013 (14).jpg', 'Sap_148 (21).jpg', 'Sap_148 (130).jpg', 'Snap_001 - Copy.jpg', 'Sap_148 (68).jpg', 'Sap_148 (119).jpg', 'Snap_006.jpg', 'Sap_148 (75).jpg', 'Sap_148 (73).jpg', 'Sn1ap_024 (7).jpg', 'Sap_013 (11).jpg', 'Sap_148 (135).jpg', 'Sap_148 (63).jpg', 'Sap_148 (25).jpg', 'Sap_148 (127).jpg', 'Sn1ap_024 (50).jpg', 'Sn1ap_024 (41).jpg', 'Sap_013 (34).jpg', 'Sap_148 (131).jpg', 'Snap_001 (4).jpg', 'Sn1ap_024 (22).jpg', 'Sap_013 (12).jpg', 'Sap_148 (90).jpg', 'Sap_148 (109).jpg', 'Sn1ap_024 (8).jpg', 'Sn1ap_024 (19).jpg', 'Sap_013 (20).jpg', 'Sap_148 (36).jpg', 'Sap_013 (17).jpg', 'Sap_148 (128).jpg', 'Sap_148 (37).jpg', 'Sap_148 (27).jpg', 'Sn1ap_024 (55).jpg', 'Sap_148 (123).jpg', 'Sap_148 (145).jpg', 'Sap_148 (122).jpg', 'Snap_006 (2).jpg', 'Sap_148 (87).jpg', 'Sap_148 (129).jpg', 'Sn1ap_024 (17).jpg', 'Snap_004 (4).jpg', 'Snap_003 (2).jpg', 'Sap_013 (23).jpg', 'Snap_007 (2).jpg', 'Sap_013 (35).jpg', 'Sap_148 (17).jpg', 'Sap_148 (8).jpg', 'Sap_148 (20).jpg', 'Sn1ap_024 (1).jpg', 'Sn1ap_024 (52).jpg', 'Sap_148 (45).jpg', 'Sn1ap_024 (58).jpg', 'Sap_148 (34).jpg', 'Sap_148 (23).jpg', 'Sap_013 (30).jpg', 'Snap_003 - Copy.jpg', 'Sap_148 (62).jpg', 'Sap_148 (59).jpg', 'Snap_007 (4).jpg', 'Sap_013 (27).jpg', 'Snap_001 (2).jpg', 'Sn1ap_024 (14).jpg', 'Sap_148 (116).jpg', 'Sap_148 (80).jpg', 'Snap_002 (2).jpg', 'Snap_008 (2).jpg', 'Sn1ap_024 (45).jpg', 'Snap_006 - Copy.jpg', 'Sap_148 (31).jpg', 'Sap_148 (52).jpg', 'Sn1ap_024 (43).jpg', 'Sap_148 (28).jpg', 'Sap_013 (44).jpg', 'Snap_004 (2).jpg', 'Sap_013 (24).jpg', 'Sap_148 (113).jpg', 'Sn1ap_024 (26).jpg', 'Sn1ap_024 (28).jpg', 'Sap_148 (144).jpg', 'Sn1ap_024 (33).jpg', 'Sn1ap_024 (35).jpg', 'Sap_013 (5).jpg', 'Sap_148 (30).jpg', 'Snap_008 - Copy.jpg', 'Sap_148 (69).jpg', 'Sn1ap_024 (42).jpg', 'Sap_148 (49).jpg', 'Sap_148 (108).jpg', 'Sap_013 (39).jpg', 'Sap_148 (84).jpg', 'Sap_013 (33).jpg', 'Snap_005.jpg', 'Sap_148 (82).jpg', 'Sap_148 (71).jpg', 'Sn1ap_024 (2).jpg', 'Sn1ap_024 (53).jpg', 'Sap_013 (41).jpg', 'Sap_148 (26).jpg', 'Sn1ap_024 (18).jpg', 'Snap_0s10.jpg', 'Sap_148 (107).jpg', 'Sn1ap_024 (20).jpg', 'Snap_005 (2).jpg', 'Snap_001.jpg', 'Sap_148 (47).jpg', 'Sap_148 (104).jpg', 'Sap_148 (141).jpg', 'Sap_013 (15).jpg', 'Sap_013 (38).jpg', 'Sn1ap_024 (34).jpg', 'Snap_003.jpg', 'Sap_148 (118).jpg', 'Sap_013 (29).jpg', 'Sap_148 (10).jpg', 'Sap_013 (37).jpg', 'Sap_148 (38).jpg', 'Sap_148 (39).jpg', 'Sap_013 (21).jpg', 'Sap_148 (103).jpg', 'Sap_013 (25).jpg', 'Sap_148 (148).jpg', 'Sap_148 (91).jpg', 'Sap_013 (9).jpg', 'Sap_148 (98).jpg', 'Sap_148 (124).jpg', 'Snap_007.jpg', 'Sap_148 (92).jpg', 'Sn1ap_024 (24).jpg', 'Sn1ap_024 (6).jpg', 'Sn1ap_024 (9).jpg', 'Sap_148 (58).jpg', 'Sn1ap_024 (29).jpg', 'Sn1ap_024 (16).jpg', 'Sap_148 (7).jpg', 'Sap_148 (132).jpg', 'Sap_148 (101).jpg', 'Sap_148 (88).jpg', 'Sap_148 (67).jpg', 'Sap_148 (139).jpg', 'Sap_148 (40).jpg', 'Sap_148 (93).jpg', 'Sap_148 (136).jpg', 'Sap_148 (115).jpg', 'Snap_001 (3).jpg', 'Sap_148 (48).jpg', 'Snap_004 (3).jpg', 'Sap_148 (55).jpg', 'Sn1ap_024 (37).jpg', 'Sap_148 (1).jpg', 'Sap_148 (152).jpg', 'Sap_148 (146).jpg', 'Sn1ap_024 (44).jpg', 'Sap_148 (134).jpg', 'Sap_148 (33).jpg', 'Sap_148 (97).jpg', 'Snap_004.jpg', 'Sap_013 (8).jpg', 'Sap_148 (117).jpg', 'Sn1ap_024 (51).jpg', 'Sap_013 (43).jpg', 'Sap_148 (64).jpg', 'Sap_148 (11).jpg', 'Sn1ap_024 (11).jpg', 'Sn1ap_024 (32).jpg', 'Sap_148 (111).jpg', 'Snap_003 (4).jpg', 'Sap_148 (2).jpg', 'Sap_148 (70).jpg', 'Sn1ap_024 (46).jpg', 'Sap_148 (9).jpg', 'Sap_148 (56).jpg', 'Sn1ap_024 (23).jpg', 'Sap_148 (24).jpg', 'Sn1ap_024 (48).jpg', 'Sap_013 (36).jpg', 'Sap_148 (76).jpg', 'Sap_148 (112).jpg', 'Sn1ap_024 (3).jpg', 'Sap_148 (18).jpg', 'Sn1ap_024 (57).jpg', 'Snap_007 - Copy.jpg', 'Sap_148 (57).jpg', 'Sap_148 (102).jpg', 'Sap_148 (140).jpg', 'Sap_013 (40).jpg', 'Snap_003 (3).jpg', 'Sn1ap_024 (59).jpg', 'Sap_148 (114).jpg', 'Sap_013 (26).jpg', 'Sap_148 (66).jpg', 'Sap_148 (96).jpg', 'Snap_007 (3).jpg', 'Sap_148 (99).jpg', 'Sap_013 (3).jpg', 'Sap_148  ...

# %%
import os
import numpy as np
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# Parameters
image_size = (128, 128)  # Resize images to 128x128
folder_path = '/content/images'

# Create folder for images (if not already done)
os.makedirs(folder_path, exist_ok=True)

# Move all images into the folder
def organize_images():
    for file_name in os.listdir('/content'):
        if file_name.endswith(('.jpg', '.png', '.jpeg')):
            os.rename(f'/content/{file_name}', f'{folder_path}/{file_name}')
    print("Images moved to folder:", folder_path)

# Preprocessing function
def preprocess_images(folder_path, image_size):
    images = []
    labels = []

    for file_name in os.listdir(folder_path):
        if file_name.endswith(('.jpg', '.png', '.jpeg')):
            # Load and resize the image
            img_path = os.path.join(folder_path, file_name)
            img = load_img(img_path, target_size=image_size)
            img_array = img_to_array(img) / 255.0  # Normalize pixel values to [0, 1]
            images.append(img_array)

            # Binary classification based on file names
            if "class_1" in file_name:  # Check for "class_1" in file name
                labels.append(0)  # Class 0
            elif "class_2" in file_name:  # Check for "class_2" in file name
                labels.append(1)  # Class 1

    return np.array(images), np.array(labels)

# Split data
def split_data(images, labels):
    X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

    # One-hot encode labels
    y_train = to_categorical(y_train, num_classes=2)  # Adjust num_classes for more classes
    y_test = to_categorical(y_test, num_classes=2)

    return X_train, X_test, y_train, y_test

# Main workflow
organize_images()  # Organize images into a folder
images, labels = preprocess_images(folder_path, image_size)  # Preprocess images
X_train, X_test, y_train, y_test = split_data(images, labels)  # Split data

# Check data shapes
print(f"Training images: {X_train.shape}, Training labels: {y_train.shape}")
print(f"Testing images: {X_test.shape}, Testing labels: {y_test.shape}")

# %%
print(os.listdir(folder_path))
# Out:
# ['Sn1ap_024 (60).jpg', 'Sap_013 (14).jpg', 'Sap_148 (21).jpg', 'Sap_148 (130).jpg', 'Snap_001 - Copy.jpg', 'Sap_148 (68).jpg', 'Sap_148 (119).jpg', 'Snap_026 (2).jpg', 'Snap_006.jpg', 'Sap_148 (75).jpg', 'Snap_018 (2).jpg', 'Sap_148 (73).jpg', 'Snap_024 (4).jpg', 'Snap_022 (4).jpg', 'Sn1ap_024 (7).jpg', 'Sap_013 (11).jpg', 'Sap_148 (135).jpg', 'Sap_148 (63).jpg', 'Sap_148 (25).jpg', 'Sap_148 (127).jpg', 'Sn1ap_024 (50).jpg', 'Sn1ap_024 (41).jpg', 'Sap_013 (34).jpg', 'Sap_148 (131).jpg', 'Snap_001 (4).jpg', 'Sn1ap_024 (22).jpg', 'Sap_013 (12).jpg', 'Snap_019.jpg', 'Sap_148 (90).jpg', 'Sap_148 (109).jpg', 'Snap_015 - Copy.jpg', 'Sn1ap_024 (8).jpg', 'Sn1ap_024 (19).jpg', 'Sap_013 (20).jpg', 'Sap_148 (36).jpg', 'Sap_013 (17).jpg', 'Sap_148 (128).jpg', 'Snap_019 (3).jpg', 'Sap_148 (37).jpg', 'Snap_023 (4).jpg', 'Sap_148 (27).jpg', 'Sn1ap_024 (55).jpg', 'Sap_148 (123).jpg', 'Snap_011.jpg', 'Sap_148 (145).jpg', 'Snap_014.jpg', 'Sap_148 (122).jpg', 'Snap_006 (2).jpg', 'Sap_148 (87).jpg', 'Sap_148 (129).jpg', 'Sn1ap_024 (17).jpg', 'Snap_004 (4).jpg', 'Snap_003 (2).jpg', 'Snap_021.jpg', 'Sap_013 (23).jpg', 'Snap_007 (2).jpg', 'Sap_013 (35).jpg', 'Sap_148 (17).jpg', 'Sap_148 (8).jpg', 'Snap_017 (2).jpg', 'Sap_148 (20).jpg', 'Sn1ap_024 (1).jpg', 'Sn1ap_024 (52).jpg', 'Snap_017 (4).jpg', 'Sap_148 (45).jpg', 'Snap_019 (4).jpg', 'Sn1ap_024 (58).jpg', 'Sap_148 (34).jpg', 'Sap_148 (23).jpg', 'Snap_015.jpg', 'Sap_013 (30).jpg', 'Snap_003 - Copy.jpg', 'Sap_148 (62).jpg', 'Sap_148 (59).jpg', 'Snap_007 (4).jpg', 'Sap_013 (27).jpg', 'Snap_001 (2).jpg', 'Sn1ap_024 (14).jpg', 'Snap_017.jpg', 'Sap_148 (116).jpg', 'Sap_148 (80).jpg', 'Snap_002 (2).jpg', 'Snap_008 (2).jpg', 'Snap_010 - Copy.jpg', 'Sn1ap_024 (45).jpg', 'Snap_027 (4).jpg', 'Snap_011 (3).jpg', 'Snap_006 - Copy.jpg', 'Sap_148 (31).jpg', 'Sap_148 (52).jpg', 'Sn1ap_024 (43).jpg', 'Sap_148 (28).jpg', 'Snap_010 (3).jpg', 'Sap_013 (44).jpg', 'Snap_004 (2).jpg', 'Snap_013.jpg', 'Snap_020 - Copy.jpg', 'Sap_013 (24).jpg', 'Snap_024 (2).jpg', 'Snap_024 (3).jpg', 'Snap_013 (2).jpg', 'Sap_148 (113).jpg', 'Snap_008 (3).jpg', 'Sn1ap_024 (26).jpg', 'Sn1ap_024 (28).jpg', 'Sap_148 (144).jpg', 'Snap_016 (2).jpg', 'Snap_021 - Copy.jpg', 'Sn1ap_024 (33).jpg', 'Sn1ap_024 (35).jpg', 'Sap_013 (5).jpg', 'Sap_148 (30).jpg', 'Snap_008 - Copy.jpg', 'Sap_148 (69).jpg', 'Sn1ap_024 (42).jpg', 'Sap_148 (49).jpg', 'Snap_008 (4).jpg', 'Sap_148 (108).jpg', 'Sap_013 (39).jpg', 'Sap_148 (84).jpg', 'Sap_013 (33).jpg', 'Snap_005.jpg', 'Snap_013 (3).jpg', 'Sap_148 (82).jpg', 'Sap_148 (71).jpg', 'Sn1ap_024 (2).jpg', 'Sn1ap_024 (53).jpg', 'Sap_013 (41).jpg', 'Sap_148 (26).jpg', 'Sn1ap_024 (18).jpg', 'Snap_0s10.jpg', 'Sap_148 (107).jpg', 'Sn1ap_024 (20).jpg', 'Snap_015 (2).jpg', 'Snap_005 (2).jpg', 'Snap_001.jpg', 'Sap_148 (47).jpg', 'Sap_148 (104).jpg', 'Snap_009 (3).jpg', 'Snap_023.jpg', 'Sap_148 (141).jpg', 'Sap_013 (15).jpg', 'Snap_012.jpg', 'Sap_013 (38).jpg', 'Snap_025 - Copy.jpg', 'Sn1ap_024 (34).jpg', 'Snap_003.jpg', 'Sap_148 (118).jpg', 'Sap_013 (29).jpg', 'Sap_148 (10).jpg', 'Sap_013 (37).jpg', 'Snap_027 (3).jpg', 'Sap_148 (38).jpg', 'Sap_148 (39).jpg', 'Sap_013 (21).jpg', 'Snap_022 - Copy.jpg', 'Sap_148 (103).jpg', 'Sap_013 (25).jpg', 'Sap_148 (148).jpg', 'Sap_148 (91).jpg', 'Sap_013 (9).jpg', 'Sap_148 (98).jpg', 'Sap_148 (124).jpg', 'Snap_007.jpg', 'Sap_148 (92).jpg', 'Sn1ap_024 (24).jpg', 'Sn1ap_024 (6).jpg', 'Sn1ap_024 (9).jpg', 'Snap_012 (2).jpg', 'Sap_148 (58).jpg', 'Sn1ap_024 (29).jpg', 'Sn1ap_024 (16).jpg', 'Sap_148 (7).jpg', 'Snap_020 (4).jpg', 'Snap_023 (3).jpg', 'Sap_148 (132).jpg', 'Sap_148 (101).jpg', 'Snap_014 (4).jpg', 'Sap_148 (88).jpg', 'Snap_023 - Copy.jpg', 'Sap_148 (67).jpg', 'Sap_148 (139).jpg', 'Sap_148 (40).jpg', 'Sap_148 (93).jpg', 'Sap_148 (136).jpg', 'Snap_009 (2).jpg', 'Sap_148 (115).jpg', 'Snap_027 (2).jpg', 'Snap_001 (3).jpg', 'Sap_148 (48).jpg', 'Snap_019 (2).jpg', 'Snap_004 (3).jpg', 'Snap_023 (2).jpg', 'Sap_148 (55).jpg', 'Sn1ap_024 (37).jpg', 'Sap_148 (1).jpg', 'Sap_148 (152).jpg', 'Sap_1 ...

# %%
if "class_1" in file_name:
    labels.append(0)
    print(f"Label 0 assigned to {file_name}")
elif "class_2" in file_name:
    labels.append(1)
    print(f"Label 1 assigned to {file_name}")

# %%
# !pip install tensorflow scikit-learn
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.6.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.12.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.69.0)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)

# %%
import os
import numpy as np
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# Parameters
image_size = (128, 128)  # Resize images to 128x128
folder_path = '/content/images'

# Create folder for images (if not already done)
os.makedirs(folder_path, exist_ok=True)

# Move all images into the folder
def organize_images():
    for file_name in os.listdir('/content'):
        if file_name.endswith(('.jpg', '.png', '.jpeg')):
            try:
                os.rename(f'/content/{file_name}', f'{folder_path}/{file_name}')
                print(f"Moved: {file_name}")
            except Exception as e:
                print(f"Error moving {file_name}: {e}")

# Preprocessing function
def preprocess_images(folder_path, image_size):
    images = []
    labels = []

    for file_name in os.listdir(folder_path):
        if file_name.endswith(('.jpg', '.png', '.jpeg')):
            img_path = os.path.join(folder_path, file_name)

            # Load and resize the image
            try:
                img = load_img(img_path, target_size=image_size)
                img_array = img_to_array(img) / 255.0  # Normalize pixel values to [0, 1]
                images.append(img_array)

                # Label based on file names
                if "class_1" in file_name:
                    labels.append(0)  # Class 0
                    print(f"Label 0 assigned to {file_name}")
                elif "class_2" in file_name:
                    labels.append(1)  # Class 1
                    print(f"Label 1 assigned to {file_name}")
                else:
                    print(f"Warning: No label for {file_name}")

            except Exception as e:
                print(f"Error processing {file_name}: {e}")

    return np.array(images), np.array(labels)

# Split data
def split_data(images, labels):
    X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

    # One-hot encode labels for multi-class classification
    y_train = to_categorical(y_train, num_classes=2)  # Adjust num_classes if needed
    y_test = to_categorical(y_test, num_classes=2)

    return X_train, X_test, y_train, y_test

# Main workflow
organize_images()  # Organize images into a folder
images, labels = preprocess_images(folder_path, image_size)  # Preprocess images

if images.size > 0 and labels.size > 0:
    X_train, X_test, y_train, y_test = split_data(images, labels)  # Split data
    # Check data shapes
    print(f"Training images: {X_train.shape}, Training labels: {y_train.shape}")
    print(f"Testing images: {X_test.shape}, Testing labels: {y_test.shape}")
else:
    print("No images or labels processed.")
# Out:
# Moved: Snap_042 - Copy.jpg
# Moved: Snap_056 (3).jpg
# Moved: Snap_042.jpg
# Moved: Snap_081 (2).jpg
# Moved: Snap_078.jpg
# Moved: Snap_030 (3).jpg
# Moved: Snap_082 (2).jpg
# Moved: Snap_084 (2).jpg
# Moved: Snap_049.jpg
# Moved: Snap_081.jpg
# Moved: Snap_065 (2).jpg
# Moved: Snap_089 (3).jpg
# Moved: Snap_054 (3).jpg
# Moved: Snap_052 - Copy.jpg
# Moved: Snap_091 (3).jpg
# Moved: Snap_047 (3).jpg
# Moved: Snap_074 (3).jpg
# Moved: Snap_087 (3).jpg
# Moved: Snap_064.jpg
# Moved: Snap_047 (2).jpg
# Moved: Snap_030 (4).jpg
# Moved: Snap_059.jpg
# Moved: Snap_066 - Copy.jpg
# Moved: Snap_070.jpg
# Moved: Snap_087.jpg
# Moved: Snap_039 (2).jpg
# Moved: Snap_044.jpg
# Moved: Snap_030 - Copy.jpg
# Moved: Snap_055.jpg
# Moved: Snap_057 (2).jpg
# Moved: Snap_033 (3).jpg
# Moved: Snap_085 - Copy.jpg
# Moved: Snap_084.jpg
# Moved: Snap_048 (2).jpg
# Moved: Snap_028 - Copy.jpg
# Moved: Snap_028 (4).jpg
# Moved: Snap_058 (2).jpg
# Moved: Snap_040.jpg
# Moved: Snap_037.jpg
# Moved: Snap_042 (2).jpg
# Moved: Snap_034 - Copy.jpg
# Moved: Snap_031 (4).jpg
# Moved: Snap_090 (3).jpg
# Moved: Snap_072 (3).jpg
# Moved: Snap_073 (2).jpg
# Moved: Snap_029 (4).jpg
# Moved: Snap_088 - Copy.jpg
# Moved: Snap_038.jpg
# Moved: Snap_057.jpg
# Moved: Snap_036 (3).jpg
# Moved: Snap_032 (4).jpg
# Moved: Snap_037 (2).jpg
# Moved: Snap_031.jpg
# Moved: Snap_073.jpg
# Moved: Snap_068 (2).jpg
# Moved: Snap_052.jpg
# Moved: Snap_067 - Copy.jpg
# Moved: Snap_061 - Copy.jpg
# Moved: Snap_069 - Copy.jpg
# Moved: Snap_048 - Copy.jpg
# Moved: Snap_064 (3).jpg
# Moved: Snap_076 (3).jpg
# Moved: Snap_085 (2).jpg
# Moved: Snap_080.jpg
# Moved: Snap_031 - Copy.jpg
# Moved: Snap_079 - Copy.jpg
# Moved: Snap_086 - Copy.jpg
# Moved: Snap_071.jpg
# Moved: Snap_053 (2).jpg
# Moved: Snap_081 - Copy.jpg
# Moved: Snap_090.jpg
# Moved: Snap_050.jpg
# Moved: Snap_049 (3).jpg
# Moved: Snap_088 (2).jpg
# Moved: Snap_073 (3).jpg
# Moved: Snap_029 (3).jpg
# Moved: Snap_058 (3).jpg
# Moved: Snap_041 (3).jpg
# Moved: Snap_075 (3).jpg
# Moved: Snap_074 - Copy.jpg
# Moved: Snap_079.jpg
# Moved: Snap_077 (3).jpg
# Moved: Snap_047 - Copy.jpg
# Moved: Snap_067.jpg
# Moved: Snap_089 (2).jpg
# Moved: Snap_041.jpg
# Moved: Snap_080 - Copy.jpg
# Moved: Snap_055 (2).jpg
# Moved: Snap_090 - Copy.jpg
# Moved: Snap_050 (2).jpg
# Moved: Snap_066.jpg
# Moved: Snap_046 (2).jpg
# Moved: Snap_051 (2).jpg
# Moved: Snap_057 - Copy.jpg
# Moved: Snap_034 (2).jpg
# Moved: Snap_062 - Copy.jpg
# Moved: Snap_046 (3).jpg
# Moved: Snap_040 - Copy.jpg
# Moved: Snap_045 - Copy.jpg
# Moved: Snap_088.jpg
# Moved: Snap_041 (2).jpg
# Moved: Snap_062 (3).jpg
# Moved: Snap_092 - Copy.jpg
# Moved: Snap_044 (3).jpg
# Moved: Snap_042 (3).jpg
# Moved: Snap_055 - Copy.jpg
# Moved: Snap_043 - Copy.jpg
# Moved: Snap_030.jpg
# Moved: Snap_048 (3).jpg
# Moved: Snap_086 (2).jpg
# Moved: Snap_028.jpg
# Moved: Snap_027 (3).jpg
# Moved: Snap_078 (2).jpg
# Moved: Snap_043 (2).jpg
# Moved: Snap_068.jpg
# Moved: Snap_081 (3).jpg
# Moved: Snap_067 (2).jpg
# Moved: Snap_091.jpg
# Moved: Snap_072 (2).jpg
# Moved: Snap_071 (2).jpg
# Moved: Snap_037 - Copy.jpg
# Moved: Snap_051.jpg
# Moved: Snap_054 - Copy.jpg
# Moved: Snap_082 (3).jpg
# Moved: Snap_032.jpg
# Moved: Snap_058 - Copy.jpg
# Moved: Snap_069 (2).jpg
# Moved: Snap_063 (2).jpg
# Moved: Snap_039.jpg
# Moved: Snap_029 - Copy.jpg
# Moved: Snap_056 (2).jpg
# Moved: Snap_061.jpg
# Moved: Snap_038 (2).jpg
# Moved: Snap_068 (3).jpg
# Moved: Snap_052 (2).jpg
# Moved: Snap_088 (3).jpg
# Moved: Snap_053 - Copy.jpg
# Moved: Snap_087 (2).jpg
# Moved: Snap_032 - Copy.jpg
# Moved: Snap_054.jpg
# Moved: Snap_080 (2).jpg
# Moved: Snap_065 - Copy.jpg
# Moved: Snap_045.jpg
# Moved: Snap_084 - Copy.jpg
# Moved: Snap_062.jpg
# Moved: Snap_065.jpg
# Moved: Snap_045 (2).jpg
# Moved: Snap_083 - Copy.jpg
# Moved: Snap_070 - Copy.jpg
# Moved: Snap_065 (3).jpg
# Moved: Snap_078 (3).jpg
# Moved: Snap_086 (3).jpg
# Moved: Snap_051 - Copy.jpg
# Moved: Snap_072.jpg
# Moved: Snap_080 (3).jpg
# Moved: Snap_033 (2).jpg
# Moved: Snap_064 (2).jpg
# Moved: Snap_036 (2).jpg
# Moved: Snap_091 (2).jpg
# Moved: Snap_031 (2).jpg
# Moved: Snap_035 - Copy.jpg
# Moved: Snap_075.jpg
# Moved: Snap_032 (2).jpg
# Moved: Snap_030 (2).jpg
# Moved: Snap_070 (3).jpg
# Moved: Snap_060 (3).jpg
# Moved: Snap_040 (2).jpg
# Moved: Snap_076 (2).jpg
# Moved: Snap_076.jpg
# Moved: Snap_062 (2).jpg
# Moved: Snap_069 (3).jpg
# Moved: Snap_060.jpg
# Moved: Snap_057 (3).jpg
# Moved: Snap_082 - Copy.jpg
# Moved: Snap_035 (2).jpg
# Moved: Snap_048.jpg
# Moved: Snap_059 - Copy.jpg
# Moved: Snap_029 (2).jpg
# Moved: Snap_061 (2).jpg
# Moved: Snap_050 - Copy.jpg
# Moved: Snap_026 (3).jpg
# Moved: Snap_052 (3).jpg
# Moved: Snap_086.jpg
# Moved: Snap_071 (3).jpg
# Moved: Snap_056 - Copy.jpg
# Moved: Snap_064 - Copy.jpg
# Moved: Snap_068 - Copy.jpg
# Moved: Snap_063 (3).jpg
# Moved: Snap_074.jpg
# Moved: Snap_093.jpg
# Moved: Snap_058.jpg
# Moved: Snap_073 - Copy.jpg
# Moved: Snap_037 (3).jpg
# Moved: Snap_033.jpg
# Moved: Snap_085 (3).jpg
# Moved: Snap_082.jpg
# Moved: Snap_084 (3).jpg
# Moved: Snap_078 - Copy.jpg
# Moved: Snap_063.jpg
# Moved: Snap_035 (3).jpg
# Moved: Snap_059 (2).jpg
# Moved: Snap_043.jpg
# Moved: Snap_072 - Copy.jpg
# Moved: Snap_044 (2).jpg
# Moved: Snap_070 (2).jpg
# Moved: Snap_053.jpg
# Moved: Snap_083 (3).jpg
# Moved: Snap_089 - Copy.jpg
# Moved: Snap_083 (2).jpg
# Moved: Snap_043 (3).jpg
# Moved: Snap_076 - Copy.jpg
# Moved: Snap_066 (2).jpg
# Moved: Snap_039 (3).jpg
# Moved: Snap_054 (2).jpg
# Moved: Snap_077.jpg
# Moved: Snap_085.jpg
# Moved: Snap_092 (2).jpg
# Moved: Snap_034.jpg
# Moved: Snap_059 (3).jpg
# Moved: Snap_091 - Copy.jpg
# Moved: Snap_029.jpg
# Moved: Snap_079 (3).jpg
# Moved: Snap_036 - Copy.jpg
# Moved: Snap_089.jpg
# Moved: Snap_031 (3).jpg
# Moved: Snap_060 - Copy.jpg
# Moved: Snap_093 (3).jpg
# Moved: Snap_079 (2).jpg
# Moved: Snap_036.jpg
# Moved: Snap_075 - Copy.jpg
# Moved: Snap_061 (3).jpg
# Moved: Snap_063 - Copy.jpg
# Moved: Snap_035.jpg
# Moved: Snap_051 (3).jpg
# Moved: Snap_038 (3).jpg
# Moved: Snap_074 (2).jpg
# Moved: Snap_077 (2).jpg
# Moved: Snap_049 (2).jpg
# Moved: Snap_047.jpg
# Moved: Snap_066 (3).jpg
# Moved: Snap_045 (3).jpg
# Moved: Snap_046 - Copy.jpg
# Moved: Snap_069.jpg
# Moved: Snap_083.jpg
# Moved: Snap_055 (3).jpg
# Moved: Snap_060 (2).jpg
# Moved: Snap_034 (3).jpg
# Moved: Snap_050 (3).jpg
# Moved: Snap_028 (3).jpg
# Moved: Snap_090 (2).jpg
# Moved: Snap_071 - Copy.jpg
# Moved: Snap_049 - Copy.jpg
# Moved: Snap_028 (2).jpg
# Moved: Snap_075 (2).jpg
# Moved: Snap_056.jpg
# Moved: Snap_067 (3).jpg
# Moved: Snap_046.jpg
# Moved: Snap_077 - Copy.jpg
# Moved: Snap_053 (3).jpg
# Moved: Snap_033 - Copy.jpg
# Moved: Snap_041 - Copy.jpg
# Moved: Snap_087 - Copy.jpg
# Moved: Snap_044 - Copy.jpg
# Moved: Snap_038 - Copy.jpg
# Moved: Snap_039 - Copy.jpg
# Moved: Snap_040 (3).jpg
# Warning: No label for Sn1ap_024 (60).jpg
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# Parameters
image_size = (128, 128)  # Resize images to 128x128
folder_path = '/content/images'

# Create folder for images (if not already done)
os.makedirs(folder_path, exist_ok=True)

# Move all images into the folder
def organize_images():
    for file_name in os.listdir('/content'):
        if file_name.endswith(('.jpg', '.png', '.jpeg')):
            try:
                os.rename(f'/content/{file_name}', f'{folder_path}/{file_name}')
                print(f"Moved: {file_name}")
            except Exception as e:
                print(f"Error moving {file_name}: {e}")

# Preprocessing function with flexible labeling
def preprocess_images(folder_path, image_size):
    images = []
    labels = []

    for file_name in os.listdir(folder_path):
        if file_name.endswith(('.jpg', '.png', '.jpeg')):
            img_path = os.path.join(folder_path, file_name)

            # Load and resize the image
            try:
                img = load_img(img_path, target_size=image_size)
                img_array = img_to_array(img) / 255.0  # Normalize pixel values to [0, 1]
                images.append(img_array)

                # Assign label based on custom conditions
                if "class_1" in file_name:
                    labels.append(0)  # Class 0
                    print(f"Label 0 assigned to {file_name}")
                elif "class_2" in file_name:
                    labels.append(1)  # Class 1
                    print(f"Label 1 assigned to {file_name}")
                else:
                    # If no label found, assign a default label (you can also manually check later)
                    labels.append(0)  # Default to Class 0 or adjust as necessary
                    print(f"Default label 0 assigned to {file_name}")

            except Exception as e:
                print(f"Error processing {file_name}: {e}")

    return np.array(images), np.array(labels)

# Split data
def split_data(images, labels):
    X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

    # One-hot encode labels for multi-class classification
    y_train = to_categorical(y_train, num_classes=2)  # Adjust num_classes if needed
    y_test = to_categorical(y_test, num_classes=2)

    return X_train, X_test, y_train, y_test

# Main workflow
organize_images()  # Organize images into a folder
images, labels = preprocess_images(folder_path, image_size)  # Preprocess images

if images.size > 0 and labels.size > 0:
    X_train, X_test, y_train, y_test = split_data(images, labels)  # Split data
    # Check data shapes
    print(f"Training images: {X_train.shape}, Training labels: {y_train.shape}")
    print(f"Testing images: {X_test.shape}, Testing labels: {y_test.shape}")
else:
    print("No images or labels processed.")
# Out:
# Moved: Snap_102 - Copy.jpg
# Moved: Snap_099 (2).jpg
# Moved: Snap_098 (2).jpg
# Moved: Snap_105 (3).jpg
# Moved: Snap_104 - Copy.jpg
# Moved: Snap_099.jpg
# Moved: Snap_094.jpg
# Moved: Snap_093 (2).jpg
# Moved: Snap_102 (3).jpg
# Moved: Snap_099 - Copy.jpg
# Moved: Snap_095 (3).jpg
# Moved: Snap_100.jpg
# Moved: Snap_093 - Copy.jpg
# Moved: Snap_101 (3).jpg
# Moved: Snap_096 - Copy.jpg
# Moved: Snap_097 - Copy.jpg
# Moved: Snap_096.jpg
# Moved: Snap_104 (3).jpg
# Moved: Snap_100 (2).jpg
# Moved: Snap_103 - Copy.jpg
# Moved: Snap_100 - Copy.jpg
# Moved: Snap_095.jpg
# Moved: Snap_098.jpg
# Moved: Snap_095 - Copy.jpg
# Moved: Snap_101.jpg
# Moved: Snap_098 - Copy.jpg
# Moved: Snap_098 (3).jpg
# Moved: Snap_094 (3).jpg
# Moved: Snap_104.jpg
# Moved: Snap_092.jpg
# Moved: Snap_103.jpg
# Moved: Snap_103 (2).jpg
# Moved: Snap_104 (2).jpg
# Moved: Snap_105 (2).jpg
# Moved: Snap_103 (3).jpg
# Moved: Snap_101 - Copy.jpg
# Moved: Snap_097 (2).jpg
# Moved: Snap_094 (2).jpg
# Moved: Snap_101 (2).jpg
# Moved: Snap_097 (3).jpg
# Moved: Snap_099 (3).jpg
# Moved: Snap_097.jpg
# Moved: Snap_094 - Copy.jpg
# Moved: Snap_105 - Copy.jpg
# Moved: Snap_096 (2).jpg
# Moved: Snap_100 (3).jpg
# Moved: Snap_102 (2).jpg
# Moved: Snap_102.jpg
# Moved: Snap_095 (2).jpg
# Moved: Snap_096 (3).jpg
# Default label 0 assigned to Snap_102 - Copy.jpg
# Default label 0 assigned to Sn1ap_024 (60).jpg
# Default label 0 assigned to Snap_042 - Copy.jpg
# Default label 0 assigned to Sap_013 (14).jpg
# Default label 0 assigned to Sap_148 (21).jpg
# Default label 0 assigned to Sap_148 (130).jpg
# Default label 0 assigned to Snap_001 - Copy.jpg
# Default label 0 assigned to Snap_056 (3).jpg
# Default label 0 assigned to Snap_042.jpg
# Default label 0 assigned to Snap_081 (2).jpg
# Default label 0 assigned to Snap_078.jpg
# Default label 0 assigned to Sap_148 (68).jpg
# Default label 0 assigned to Sap_148 (119).jpg
# Default label 0 assigned to Snap_026 (2).jpg
# Default label 0 assigned to Snap_030 (3).jpg
# Default label 0 assigned to Snap_082 (2).jpg
# Default label 0 assigned to Snap_006.jpg
# Default label 0 assigned to Sap_148 (75).jpg
# Default label 0 assigned to Snap_018 (2).jpg
# Default label 0 assigned to Snap_084 (2).jpg
# Default label 0 assigned to Snap_049.jpg
# Default label 0 assigned to Sap_148 (73).jpg
# Default label 0 assigned to Snap_024 (4).jpg
# Default label 0 assigned to Snap_022 (4).jpg
# Default label 0 assigned to Sn1ap_024 (7).jpg
# Default label 0 assigned to Sap_013 (11).jpg
# Default label 0 assigned to Snap_081.jpg
# Default label 0 assigned to Sap_148 (135).jpg
# Default label 0 assigned to Snap_065 (2).jpg
# Default label 0 assigned to Snap_089 (3).jpg
# Default label 0 assigned to Sap_148 (63).jpg
# Default label 0 assigned to Snap_054 (3).jpg
# Default label 0 assigned to Sap_148 (25).jpg
# Default label 0 assigned to Snap_052 - Copy.jpg
# Default label 0 assigned to Sap_148 (127).jpg
# Default label 0 assigned to Snap_091 (3).jpg
# Default label 0 assigned to Snap_047 (3).jpg
# Default label 0 assigned to Sn1ap_024 (50).jpg
# Default label 0 assigned to Sn1ap_024 (41).jpg
# Default label 0 assigned to Sap_013 (34).jpg
# Default label 0 assigned to Snap_074 (3).jpg
# Default label 0 assigned to Snap_087 (3).jpg
# Default label 0 assigned to Snap_064.jpg
# Default label 0 assigned to Snap_047 (2).jpg
# Default label 0 assigned to Sap_148 (131).jpg
# Default label 0 assigned to Snap_030 (4).jpg
# Default label 0 assigned to Snap_099 (2).jpg
# Default label 0 assigned to Snap_001 (4).jpg
# Default label 0 assigned to Sn1ap_024 (22).jpg
# Default label 0 assigned to Snap_098 (2).jpg
# Default label 0 assigned to Sap_013 (12).jpg
# Default label 0 assigned to Snap_019.jpg
# Default label 0 assigned to Sap_148 (90).jpg
# Default label 0 assigned to Sap_148 (109).jpg
# Default label 0 assigned to Snap_015 - Copy.jpg
# Default label 0 assigned to Sn1ap_024 (8).jpg
# Default label 0 assigned to Sn1ap_024 (19).jpg
# Default label 0 assigned to Sap_013 (20).jpg
# Default label 0 assigned to Snap_059.jpg
# Default label 0 assigned to Snap_066 - Copy.jpg
# Default label 0 assigned to Snap_070.jpg
# Default label 0 assigned to Snap_087.jpg
# Default label 0 assigned to Sap_148 (36).jpg
# Default label 0 assigned to Snap_039 (2).jpg
# Default label 0 assigned to Sap_013 (17).jpg
# Default label 0 assigned to Sap_148 (128).jpg
# Default label 0 assigned to Snap_105 (3).jpg
# Default label 0 assigned to Snap_044.jpg
# Default label 0 assigned to Snap_019 (3).jpg
# Default label 0 assigned to Snap_030 - Copy.jpg
# Default label 0 assigned to Sap_148 (37).jpg
# Default label 0 assigned to Snap_055.jpg
# Default label 0 assigned to Snap_023 (4).jpg
# Default label 0 assigned to Sap_148 (27).jpg
# Default label 0 assigned to Sn1ap_024 (55).jpg
# Default label 0 assigned to Snap_104 - Copy.jpg
# Default label 0 assigned to Snap_057 (2).jpg
# Default label 0 assigned to Snap_033 (3).jpg
# Default label 0 assigned to Sap_148 (123).jpg
# Default label 0 assigned to Snap_011.jpg
# Default label 0 assigned to Sap_148 (145).jpg
# Default label 0 assigned to Snap_099.jpg
# Default label 0 assigned to Snap_014.jpg
# Default label 0 assigned to Sap_148 (122).jpg
# Default label 0 assigned to Snap_085 - Copy.jpg
# Default label 0 assigned to Snap_006 (2).jpg
# Default label 0 assigned to Snap_084.jpg
# Default label 0 assigned to Sap_148 (87).jpg
# Default label 0 assigned to Sap_148 (129).jpg
# Default label 0 assigned to Snap_048 (2).jpg
# Default label 0 assigned to Sn1ap_024 (17).jpg
# Default label 0 assigned to Snap_004 (4).jpg
# Default label 0 assigned to Snap_003 (2).jpg
# Default label 0 assigned to Snap_021.jpg
# Default label 0 assigned to Snap_028 - Copy.jpg
# Default label 0 assigned to Sap_013 (23).jpg
# Default label 0 assigned to Snap_007 (2).jpg
# Default label 0 assigned to Sap_013 (35).jpg
# Default label 0 assigned to Snap_094.jpg
# Default label 0 assigned to Snap_028 (4).jpg
# Default label 0 assigned to Sap_148 (17).jpg
# Default label 0 assigned to Snap_093 (2).jpg
# Default label 0 assigned to Snap_058 (2).jpg
# Default label 0 assigned to Snap_040.jpg
# Default label 0 assigned to Snap_037.jpg
# Default label 0 assigned to Snap_042 (2).jpg
# Default label 0 assigned to Snap_034 - Copy.jpg
# Default label 0 assigned to Sap_148 (8).jpg
# Default label 0 assigned to Snap_017 (2).jpg
# Default label 0 assigned to Snap_031 (4).jpg
# Default label 0 assigned to Sap_148 (20).jpg
# Default label 0 assigned to Sn1ap_024 (1).jpg
# Default label 0 assigned to Sn1ap_024 (52).jpg
# Default label 0 assigned to Snap_017 (4).jpg
# Default label 0 assigned to Sap_148 (45).jpg
# Default label 0 assigned to Snap_019 (4).jpg
# Default label 0 assigned to Sn1ap_024 (58).jpg
# Default label 0 assigned to Snap_090 (3).jpg
# Default label 0 assigned to Sap_148 (34).jpg
# Default label 0 assigned to Snap_072 (3).jpg
# Default label 0 assigned to Snap_073 (2).jpg
# Default label 0 assigned to Sap_148 (23).jpg
# Default label 0 assigned to Snap_015.jpg
# Default label 0 assigned to Sap_013 (30).jpg
# Default label 0 assigned to Snap_029 (4).jpg
# Default label 0 assigned to Snap_088 - Copy.jpg
# Default label 0 assigned to Snap_038.jpg
# Default label 0 assigned to Snap_057.jpg
# Default label 0 assigned to Snap_003 - Copy.jpg
# Default label 0 assigned to Snap_036 (3).jpg
# Default label 0 assigned to Sap_148 (62).jpg
# Default label 0 assigned to Snap_032 (4).jpg
# Default label 0 assigned to Sap_148 (59).jpg
# Default label 0 assigned to Snap_102 (3).jpg
# Default label 0 assigned to Snap_007 (4).jpg
# Default label 0 assigned to Sap_013 (27).jpg
# Default label 0 assigned to Snap_037 (2).jpg
# Default label 0 assigned to Snap_031.jpg
# Default label 0 assigned to Snap_073.jpg
# Default label 0 assigned to Snap_001 (2).jpg
# Default label 0 assigned to Snap_068 (2).jpg
# Default label 0 assigned to Snap_052.jpg
# Default label 0 assigned to Sn1ap_024 (14).jpg
# Default label 0 assigned to Snap_067 - Copy.jpg
# Default label 0 assigned to Snap_061 - Copy.jpg
# Default label 0 assigned to Snap_017.jpg
# Default label 0 assigned to Snap_069 - Copy.jpg
# Default label 0 assigned to Sap_148 (116).jpg
# Default label 0 assigned to Sap_148 (80).jpg
# Default label 0 assigned to Snap_002 (2).jpg
# Default label 0 assigned to Snap_048 - Copy.jpg
# Default label 0 assigned to Snap_064 (3).jpg
# Default label 0 assigned to Snap_008 (2).jpg
# Default label 0 assigned to Snap_010 - Copy.jpg
# Default label 0 assigned to Sn1ap_024 (45).jpg
# Default label 0 assigned to Snap_076 (3).jpg
# Default label 0 assigned to Snap_027 (4).jpg
# Default label 0 assigned to Snap_011 (3).jpg
# Default label 0 assigned to Snap_085 (2).jpg
# Default label 0 assigned to Snap_006 - Copy.jpg
# Default label 0 assigned to Sap_148 (31).jpg
# Default label 0 assigned to Snap_080.jpg
# Default label 0 assigned to Sap_148 (52).jpg
# Default label 0 assigned to Sn1ap_024 (43).jpg
# Default label 0 assigned to Sap_148 (28).jpg
# Default label 0 assigned to Snap_010 (3).jpg
# Default label 0 assigned to Sap_013 (44).jpg
# Default label 0 assigned to Snap_004 (2).jpg
# Default label 0 assigned to Snap_013.jpg
# Default label 0 assigned to Snap_020 - Copy.jpg
# Default label 0 assigned to Sap_013 (24).jpg
# Default label 0 assigned to Snap_031 - Copy.jpg
# Default label 0 assigned to Snap_024 (2).jpg
# Default label 0 assigned to Snap_024 (3).jpg
# Default label 0 assigned to Snap_099 - Copy.jpg
# Default label 0 assigned to Snap_013 (2).jpg
# Default label 0 assigned to Snap_079 - Copy.jpg
# Default label 0 assigned to Snap_086 - Copy.jpg
# Default label 0 assigned to Sap_148 (113).jpg
# Default label 0 assigned to Snap_008 (3).jpg
# Default label 0 assigned to Sn1ap_024 (26).jpg
# Default label 0 assigned to Sn1ap_024 (28).jpg
# Default label 0 assigned to Sap_148 (144).jpg
# Default label 0 assigned to Snap_016 (2).jpg
# Default label 0 assigned to Snap_071.jpg
# Default label 0 assigned to Snap_053 (2).jpg
# Default label 0 assigned to Snap_081 - Copy.jpg
# Default label 0 assigned to Snap_090.jpg
# Default label 0 assigned to Snap_050.jpg
# Default label 0 assigned to Snap_049 (3).jpg
# Default label 0 assigned to Snap_021 - Copy.jpg
# Default label 0 assigned to Sn1ap_024 (33).jpg
# Default label 0 assigned to Snap_088 (2).jpg
# Default label 0 assigned to Snap_073 (3).jpg
# Default label 0 assigned to Sn1ap_024 (35).jpg
# Default label 0 assigned to Snap_029 (3).jpg
# Default label 0 assigned to Sap_013 (5).jpg
# Default label 0 assigned to Sap_148 (30).jpg
# Default label 0 assigned to Snap_058 (3).jpg
# Default label 0 assigned to Snap_008 - Copy.jpg
# Default label 0 assigned to Sap_148 (69).jpg
# Default label 0 assigned to Sn1ap_024 (42).jpg
# Default label 0 assigned to Sap_148 (49).jpg
# Default label 0 assigned to Snap_041 (3).jpg
# Default label 0 assigned to Snap_075 (3).jpg
# Default label 0 assigned to Snap_074 - Copy.jpg
# Default label 0 assigned to Snap_079.jpg
# Default label 0 assigned to Snap_008 (4).jpg
# Default label 0 assigned to Snap_077 (3).jpg
# Default label 0 assigned to Snap_047 - Copy.jpg
# Default label 0 assigned to Snap_067.jpg
# Default label 0 assigned to Snap_095 (3).jpg
# Default label 0 assigned to Sap_148 (108).jpg
# Default label 0 assigned to Sap_013 (39).jpg
# Default label 0 assigned to Snap_089 (2).jpg
# Default label 0 assigned to Snap_041.jpg
# Default label 0 assigned to Snap_100.jpg
# Default label 0 assigned to Sap_148 (84).jpg
# Default label 0 assigned to Snap_080 - Copy.jpg
# Default label 0 assigned to Sap_013 (33).jpg
# Default label 0 assigned to Snap_093 - Copy.jpg
# Default label 0 assigned to Snap_101 (3).jpg
# Default label 0 assigned to Snap_005.jpg
# Default label 0 assigned to Snap_055 (2).jpg
# Default label 0 assigned to Snap_013 (3).jpg
# Default label 0 assigned to Sap_148 (82).jpg
# Default label 0 assigned to Snap_096 - Copy.jpg
# Default label 0 assigned to Sap_148 (71).jpg
# Default label 0 assigned to Snap_090 - Copy.jpg
# Default label 0 assigned to Snap_097 - Copy.jpg
# Default label 0 assigned to Sn1ap_024 (2).jpg
# Default label 0 assigned to Sn1ap_024 (53).jpg
# Default label 0 assigned to Sap_013 (41).jpg
# Default label 0 assigned to Snap_050 (2).jpg
# Default label 0 assigned to Sap_148 (26).jpg
# Default label 0 assigned to Snap_096.jpg
# Default label 0 assigned to Snap_066.jpg
# Default label 0 assigned to Snap_046 (2).jpg
# Default label 0 assigned to Snap_051 (2).jpg
# Default label 0 assigned to Sn1ap_024 (18).jpg
# Default label 0 assigned to Snap_0s10.jpg
# Default label 0 assigned to Snap_057 - Copy.jpg
# Default label 0 assigned to Sap_148 (107).jpg
# Default label 0 assigned to Sn1ap_024 (20).jpg
# Default label 0 assigned to Snap_034 (2).jpg
# Default label 0 assigned to Snap_062 - Copy.jpg
# Default label 0 assigned to Snap_046 (3).jpg
# Default label 0 assigned to Snap_040 - Copy.jpg
# Default label 0 assigned to Snap_045 - Copy.jpg
# Default label 0 assigned to Snap_088.jpg
# Default label 0 assigned to Snap_015 (2).jpg
# Default label 0 assigned to Snap_005 (2).jpg
# Default label 0 assigned to Snap_001.jpg
# Default label 0 assigned to Snap_041 (2).jpg
# Default label 0 assigned to Snap_062 (3).jpg
# Default label 0 assigned to Snap_092 - Copy.jpg
# Default label 0 assigned to Sap_148 (47).jpg
# Default label 0 assigned to Snap_044 (3).jpg
# Default label 0 assigned to Snap_042 (3).jpg
# Default label 0 assigned to Sap_148 (104).jpg
# Default label 0 assigned to Snap_009 (3).jpg
# Default label 0 assigned to Snap_023.jpg
# Default label 0 assigned to Sap_148 (141).jpg
# Default label 0 assigned to Sap_013 (15).jpg
# Default label 0 assigned to Snap_055 - Copy.jpg
# Default label 0 assigned to Snap_012.jpg
# Default label 0 assigned to Sap_013 (38).jpg
# Default label 0 assigned to Snap_043 - Copy.jpg
# Default label 0 assigned to Snap_030.jpg
# Default label 0 assigned to Snap_048 (3).jpg
# Default label 0 assigned to Snap_025 - Copy.jpg
# Default label 0 assigned to Snap_086 (2).jpg
# Default label 0 assigned to Sn1ap_024 (34).jpg
# Default label 0 assigned to Snap_003.jpg
# Default label 0 assigned to Sap_148 (118).jpg
# Default label 0 assigned to Sap_013 (29).jpg
# Default label 0 assigned to Snap_104 (3).jpg
# Default label 0 assigned to Sap_148 (10).jpg
# Default label 0 assigned to Snap_028.jpg
# Default label 0 assigned to Sap_013 (37).jpg
# Error processing Snap_027 (3).jpg: cannot identify image file <_io.BytesIO object at 0x79acb2ab6c00>
# Default label 0 assigned to Snap_078 (2).jpg
# Default label 0 assigned to Snap_043 (2).jpg
# Default label 0 assigned to Sap_148 (38).jpg
# Default label 0 assigned to Snap_100 (2).jpg
# Default label 0 assigned to Sap_148 (39).jpg
# Default label 0 assigned to Sap_013 (21).jpg
# Default label 0 assigned to Snap_022 - Copy.jpg
# Default label 0 assigned to Sap_148 (103).jpg
# Default label 0 assigned to Sap_013 (25).jpg
# Default label 0 assigned to Sap_148 (148).jpg
# Default label 0 assigned to Snap_103 - Copy.jpg
# Default label 0 assigned to Snap_068.jpg
# Default label 0 assigned to Snap_081 (3).jpg
# Default label 0 assigned to Snap_067 (2).jpg
# Default label 0 assigned to Sap_148 (91).jpg
# Default label 0 assigned to Sap_013 (9).jpg
# Default label 0 assigned to Snap_091.jpg
# Default label 0 assigned to Snap_072 (2).jpg
# Default label 0 assigned to Snap_100 - Copy.jpg
# Default label 0 assigned to Snap_071 (2).jpg
# Default label 0 assigned to Snap_037 - Copy.jpg
# Default label 0 assigned to Sap_148 (98).jpg
# Default label 0 assigned to Sap_148 (124).jpg
# Default label 0 assigned to Snap_051.jpg
# Default label 0 assigned to Snap_007.jpg
# Default label 0 assigned to Snap_054 - Copy.jpg
# Default label 0 assigned to Snap_082 (3).jpg
# Default label 0 assigned to Snap_032.jpg
# Default label 0 assigned to Snap_095.jpg
# Default label 0 assigned to Sap_148 (92).jpg
# Default label 0 assigned to Sn1ap_024 (24).jpg
# Default label 0 assigned to Sn1ap_024 (6).jpg
# Default label 0 assigned to Sn1ap_024 (9).jpg
# Default label 0 assigned to Snap_058 - Copy.jpg
# Default label 0 assigned to Snap_012 (2).jpg
# Default label 0 assigned to Snap_069 (2).jpg
# Default label 0 assigned to Sap_148 (58).jpg
# Default label 0 assigned to Sn1ap_024 (29).jpg
# Default label 0 assigned to Sn1ap_024 (16).jpg
# Default label 0 assigned to Sap_148 (7).jpg
# Default label 0 assigned to Snap_063 (2).jpg
# Default label 0 assigned to Snap_098.jpg
# Default label 0 assigned to Snap_020 (4).jpg
# Default label 0 assigned to Snap_023 (3).jpg
# Default label 0 assigned to Sap_148 (132).jpg
# Default label 0 assigned to Sap_148 (101).jpg
# Default label 0 assigned to Snap_039.jpg
# Default label 0 assigned to Snap_029 - Copy.jpg
# Default label 0 assigned to Snap_056 (2).jpg
# Default label 0 assigned to Snap_014 (4).jpg
# Default label 0 assigned to Snap_061.jpg
# Default label 0 assigned to Snap_095 - Copy.jpg
# Default label 0 assigned to Snap_038 (2).jpg
# Default label 0 assigned to Sap_148 (88).jpg
# Default label 0 assigned to Snap_023 - Copy.jpg
# Default label 0 assigned to Snap_068 (3).jpg
# Default label 0 assigned to Snap_052 (2).jpg
# Default label 0 assigned to Snap_088 (3).jpg
# Default label 0 assigned to Snap_053 - Copy.jpg
# Default label 0 assigned to Snap_087 (2).jpg
# Default label 0 assigned to Sap_148 (67).jpg
# Default label 0 assigned to Snap_032 - Copy.jpg
# Default label 0 assigned to Sap_148 (139).jpg
# Default label 0 assigned to Sap_148 (40).jpg
# Default label 0 assigned to Snap_054.jpg
# Default label 0 assigned to Sap_148 (93).jpg
# Default label 0 assigned to Sap_148 (136).jpg
# Default label 0 assigned to Snap_009 (2).jpg
# Default label 0 assigned to Sap_148 (115).jpg
# Default label 0 assigned to Snap_027 (2).jpg
# Default label 0 assigned to Snap_001 (3).jpg
# Default label 0 assigned to Sap_148 (48).jpg
# Default label 0 assigned to Snap_080 (2).jpg
# Default label 0 assigned to Snap_065 - Copy.jpg
# Default label 0 assigned to Snap_019 (2).jpg
# Default label 0 assigned to Snap_045.jpg
# Default label 0 assigned to Snap_004 (3).jpg
# Default label 0 assigned to Snap_101.jpg
# Default label 0 assigned to Snap_084 - Copy.jpg
# Default label 0 assigned to Snap_023 (2).jpg
# Default label 0 assigned to Sap_148 (55).jpg
# Default label 0 assigned to Sn1ap_024 (37).jpg
# Default label 0 assigned to Snap_062.jpg
# Default label 0 assigned to Snap_065.jpg
# Default label 0 assigned to Snap_045 (2).jpg
# Default label 0 assigned to Sap_148 (1).jpg
# Default label 0 assigned to Sap_148 (152).jpg
# Default label 0 assigned to Snap_083 - Copy.jpg
# Default label 0 assigned to Snap_070 - Copy.jpg
# Default label 0 assigned to Sap_148 (146).jpg
# Default label 0 assigned to Snap_065 (3).jpg
# Default label 0 assigned to Snap_078 (3).jpg
# Default label 0 assigned to Snap_009.jpg
# Default label 0 assigned to Snap_086 (3).jpg
# Default label 0 assigned to Snap_051 - Copy.jpg
# Default label 0 assigned to Snap_072.jpg
# Default label 0 assigned to Snap_080 (3).jpg
# Default label 0 assigned to Sn1ap_024 (44).jpg
# Default label 0 assigned to Sap_148 (134).jpg
# Default label 0 assigned to Sap_148 (33).jpg
# Default label 0 assigned to Snap_033 (2).jpg
# Default label 0 assigned to Snap_064 (2).jpg
# Default label 0 assigned to Snap_015 (3).jpg
# Default label 0 assigned to Sap_148 (97).jpg
# Default label 0 assigned to Snap_022 (2).jpg
# Default label 0 assigned to Snap_036 (2).jpg
# Default label 0 assigned to Snap_091 (2).jpg
# Default label 0 assigned to Snap_031 (2).jpg
# Default label 0 assigned to Snap_035 - Copy.jpg
# Default label 0 assigned to Snap_004.jpg
# Default label 0 assigned to Snap_075.jpg
# Default label 0 assigned to Snap_032 (2).jpg
# Default label 0 assigned to Sap_013 (8).jpg
# Default label 0 assigned to Sap_148 (117).jpg
# Default label 0 assigned to Snap_030 (2).jpg
# Default label 0 assigned to Snap_015 (4).jpg
# Default label 0 assigned to Snap_013 (4).jpg
# Default label 0 assigned to Sn1ap_024 (51).jpg
# Default label 0 assigned to Snap_070 (3).jpg
# Default label 0 assigned to Sap_013 (43).jpg
# Default label 0 assigned to Snap_060 (3).jpg
# Default label 0 assigned to Snap_027.jpg
# Default label 0 assigned to Snap_040 (2).jpg
# Default label 0 assigned to Snap_076 (2).jpg
# Default label 0 assigned to Sap_148 (64).jpg
# Default label 0 assigned to Snap_076.jpg
# Default label 0 assigned to Snap_062 (2).jpg
# Default label 0 assigned to Snap_069 (3).jpg
# Default label 0 assigned to Sap_148 (11).jpg
# Default label 0 assigned to Snap_021 (3).jpg
# Default label 0 assigned to Snap_060.jpg
# Default label 0 assigned to Sn1ap_024 (11).jpg
# Default label 0 assigned to Snap_057 (3).jpg
# Default label 0 assigned to Snap_025.jpg
# Default label 0 assigned to Sn1ap_024 (32).jpg
# Default label 0 assigned to Sap_148 (111).jpg
# Default label 0 assigned to Snap_082 - Copy.jpg
# Default label 0 assigned to Snap_026 (4).jpg
# Default label 0 assigned to Snap_035 (2).jpg
# Default label 0 assigned to Snap_048.jpg
# Default label 0 assigned to Snap_003 (4).jpg
# Default label 0 assigned to Snap_059 - Copy.jpg
# Default label 0 assigned to Snap_029 (2).jpg
# Default label 0 assigned to Snap_061 (2).jpg
# Default label 0 assigned to Sap_148 (2).jpg
# Default label 0 assigned to Sap_148 (70).jpg
# Default label 0 assigned to Snap_050 - Copy.jpg
# Error processing Snap_026 (3).jpg: cannot identify image file <_io.BytesIO object at 0x79ad3074ede0>
# Default label 0 assigned to Sn1ap_024 (46).jpg
# Default label 0 assigned to Snap_052 (3).jpg
# Default label 0 assigned to Sap_148 (9).jpg
# Default label 0 assigned to Sap_148 (56).jpg
# Default label 0 assigned to Snap_086.jpg
# Default label 0 assigned to Sn1ap_024 (23).jpg
# Default label 0 assigned to Snap_071 (3).jpg
# Default label 0 assigned to Sap_148 (24).jpg
# Default label 0 assigned to Sn1ap_024 (48).jpg
# Default label 0 assigned to Snap_098 - Copy.jpg
# Default label 0 assigned to Sap_013 (36).jpg
# Default label 0 assigned to Snap_098 (3).jpg
# Default label 0 assigned to Snap_056 - Copy.jpg
# Default label 0 assigned to Sap_148 (76).jpg
# Default label 0 assigned to Sap_148 (112).jpg
# Default label 0 assigned to Snap_064 - Copy.jpg
# Default label 0 assigned to Sn1ap_024 (3).jpg
# Default label 0 assigned to Sap_148 (18).jpg
# Default label 0 assigned to Sn1ap_024 (57).jpg
# Default label 0 assigned to Snap_094 (3).jpg
# Default label 0 assigned to Snap_007 - Copy.jpg
# Default label 0 assigned to Snap_104.jpg
# Default label 0 assigned to Sap_148 (57).jpg
# Default label 0 assigned to Sap_148 (102).jpg
# Default label 0 assigned to Snap_021 (4).jpg
# Default label 0 assigned to Sap_148 (140).jpg
# Default label 0 assigned to Sap_013 (40).jpg
# Default label 0 assigned to Snap_024 - Copy.jpg
# Default label 0 assigned to Snap_068 - Copy.jpg
# Default label 0 assigned to Snap_003 (3).jpg
# Default label 0 assigned to Snap_063 (3).jpg
# Default label 0 assigned to Snap_074.jpg
# Default label 0 assigned to Snap_093.jpg
# Default label 0 assigned to Sn1ap_024 (59).jpg
# Default label 0 assigned to Sap_148 (114).jpg
# Default label 0 assigned to Snap_058.jpg
# Default label 0 assigned to Snap_073 - Copy.jpg
# Default label 0 assigned to Snap_037 (3).jpg
# Default label 0 assigned to Snap_021 (2).jpg
# Default label 0 assigned to Sap_013 (26).jpg
# Default label 0 assigned to Snap_033.jpg
# Default label 0 assigned to Sap_148 (66).jpg
# Default label 0 assigned to Snap_009 - Copy.jpg
# Default label 0 assigned to Sap_148 (96).jpg
# Default label 0 assigned to Snap_025 (4).jpg
# Error processing Snap_007 (3).jpg: cannot identify image file <_io.BytesIO object at 0x79acb2a9cea0>
# Default label 0 assigned to Sap_148 (99).jpg
# Default label 0 assigned to Sap_013 (3).jpg
# Default label 0 assigned to Snap_085 (3).jpg
# Default label 0 assigned to Sap_148 (60).jpg
# Default label 0 assigned to Snap_010 (2).jpg
# Default label 0 assigned to Snap_026 - Copy.jpg
# Default label 0 assigned to Snap_016 - Copy.jpg
# Default label 0 assigned to Snap_082.jpg
# Default label 0 assigned to Sap_013 (7).jpg
# Default label 0 assigned to Sap_013 (16).jpg
# Default label 0 assigned to Sap_148 (72).jpg
# Default label 0 assigned to Snap_092.jpg
# Default label 0 assigned to Sap_148 (46).jpg
# Default label 0 assigned to Sn1ap_024 (10).jpg
# Default label 0 assigned to Snap_084 (3).jpg
# Default label 0 assigned to Sap_148 (19).jpg
# Default label 0 assigned to Sap_148 (120).jpg
# Default label 0 assigned to Snap_078 - Copy.jpg
# Default label 0 assigned to Sap_148 (51).jpg
# Default label 0 assigned to Sap_148 (5).jpg
# Default label 0 assigned to Snap_063.jpg
# Default label 0 assigned to Snap_035 (3).jpg
# Default label 0 assigned to Snap_059 (2).jpg
# Default label 0 assigned to Snap_043.jpg
# Default label 0 assigned to Snap_014 - Copy.jpg
# Default label 0 assigned to Snap_103.jpg
# Default label 0 assigned to Snap_103 (2).jpg
# Default label 0 assigned to Snap_104 (2).jpg
# Default label 0 assigned to Snap_022 (3).jpg
# Default label 0 assigned to Snap_00s2.jpg
# Default label 0 assigned to Sap_148 (43).jpg
# Default label 0 assigned to Sap_148 (95).jpg
# Default label 0 assigned to Sap_148 (121).jpg
# Default label 0 assigned to Snap_0s08.jpg
# Default label 0 assigned to Snap_005 (3).jpg
# Default label 0 assigned to Snap_105 (2).jpg
# Default label 0 assigned to Sap_148 (100).jpg
# Default label 0 assigned to Snap_072 - Copy.jpg
# Default label 0 assigned to Sap_148 (125).jpg
# Default label 0 assigned to Snap_044 (2).jpg
# Default label 0 assigned to Snap_020 (3).jpg
# Default label 0 assigned to Sap_013 (32).jpg
# Default label 0 assigned to Sap_013 (4).jpg
# Default label 0 assigned to Snap_025 (3).jpg
# Default label 0 assigned to Snap_103 (3).jpg
# Default label 0 assigned to Snap_070 (2).jpg
# Default label 0 assigned to Snap_053.jpg
# Default label 0 assigned to Snap_002 (3).jpg
# Default label 0 assigned to Sap_148 (4).jpg
# Default label 0 assigned to Snap_016 (3).jpg
# Default label 0 assigned to Snap_011 - Copy.jpg
# Default label 0 assigned to Sap_013 (2).jpg
# Default label 0 assigned to Sap_148 (105).jpg
# Default label 0 assigned to Snap_083 (3).jpg
# Default label 0 assigned to Snap_089 - Copy.jpg
# Default label 0 assigned to Snap_083 (2).jpg
# Default label 0 assigned to Sap_148 (110).jpg
# Default label 0 assigned to Snap_005 - Copy.jpg
# Default label 0 assigned to Sap_148 (74).jpg
# Default label 0 assigned to Sap_148 (35).jpg
# Default label 0 assigned to Snap_043 (3).jpg
# Default label 0 assigned to Snap_076 - Copy.jpg
# Default label 0 assigned to Snap_066 (2).jpg
# Default label 0 assigned to Snap_039 (3).jpg
# Default label 0 assigned to Sn1ap_024 (4).jpg
# Default label 0 assigned to Snap_054 (2).jpg
# Default label 0 assigned to Snap_002.jpg
# Default label 0 assigned to Snap_101 - Copy.jpg
# Default label 0 assigned to Sap_013 (28).jpg
# Default label 0 assigned to Snap_002 (4).jpg
# Default label 0 assigned to Snap_077.jpg
# Default label 0 assigned to Snap_085.jpg
# Default label 0 assigned to Snap_092 (2).jpg
# Default label 0 assigned to Sn1ap_024 (49).jpg
# Default label 0 assigned to Sn1ap_024 (47).jpg
# Default label 0 assigned to Sn1ap_024 (5).jpg
# Default label 0 assigned to Sn1ap_024 (39).jpg
# Default label 0 assigned to Snap_034.jpg
# Default label 0 assigned to Snap_018.jpg
# Default label 0 assigned to Snap_059 (3).jpg
# Default label 0 assigned to Snap_091 - Copy.jpg
# Default label 0 assigned to Snap_029.jpg
# Default label 0 assigned to Snap_009 (4).jpg
# Default label 0 assigned to Snap_017 - Copy.jpg
# Default label 0 assigned to Snap_010 (4).jpg
# Default label 0 assigned to Snap_016.jpg
# Default label 0 assigned to Sap_013 (31).jpg
# Default label 0 assigned to Sn1ap_024 (31).jpg
# Default label 0 assigned to Sap_148 (81).jpg
# Default label 0 assigned to Snap_004 - Copy.jpg
# Default label 0 assigned to Snap_097 (2).jpg
# Default label 0 assigned to Snap_094 (2).jpg
# Default label 0 assigned to Snap_019 - Copy.jpg
# Default label 0 assigned to Sap_013 (19).jpg
# Default label 0 assigned to Snap_017 (3).jpg
# Default label 0 assigned to Snap_079 (3).jpg
# Default label 0 assigned to Sap_148 (50).jpg
# Default label 0 assigned to Sap_148 (78).jpg
# Default label 0 assigned to Snap_036 - Copy.jpg
# Default label 0 assigned to Snap_089.jpg
# Default label 0 assigned to Snap_031 (3).jpg
# Default label 0 assigned to Sap_148 (42).jpg
# Default label 0 assigned to Sap_013 (18).jpg
# Default label 0 assigned to Snap_101 (2).jpg
# Default label 0 assigned to Sap_148 (89).jpg
# Default label 0 assigned to Snap_060 - Copy.jpg
# Default label 0 assigned to Sap_148 (54).jpg
# Default label 0 assigned to Sap_013 (13).jpg
# Default label 0 assigned to Snap_093 (3).jpg
# Default label 0 assigned to Sap_148 (83).jpg
# Default label 0 assigned to Snap_079 (2).jpg
# Default label 0 assigned to Sap_148 (32).jpg
# Default label 0 assigned to Snap_036.jpg
# Default label 0 assigned to Snap_018 - Copy.jpg
# Default label 0 assigned to Snap_075 - Copy.jpg
# Default label 0 assigned to Sap_013 (10).jpg
# Default label 0 assigned to Snap_061 (3).jpg
# Default label 0 assigned to Sn1ap_024 (38).jpg
# Default label 0 assigned to Snap_097 (3).jpg
# Default label 0 assigned to Sn1ap_024 (27).jpg
# Default label 0 assigned to Snap_016 (4).jpg
# Default label 0 assigned to Snap_063 - Copy.jpg
# Default label 0 assigned to Snap_035.jpg
# Default label 0 assigned to Sap_148 (79).jpg
# Default label 0 assigned to Snap_051 (3).jpg
# Default label 0 assigned to Snap_010.jpg
# Default label 0 assigned to Sn1ap_024 (25).jpg
# Default label 0 assigned to Snap_099 (3).jpg
# Default label 0 assigned to Snap_038 (3).jpg
# Default label 0 assigned to Snap_074 (2).jpg
# Default label 0 assigned to Snap_077 (2).jpg
# Default label 0 assigned to Snap_012 - Copy.jpg
# Default label 0 assigned to Sap_148 (3).jpg
# Default label 0 assigned to Snap_097.jpg
# Default label 0 assigned to Sap_148 (86).jpg
# Default label 0 assigned to Snap_049 (2).jpg
# Default label 0 assigned to Snap_020 (2).jpg
# Default label 0 assigned to Snap_014 (2).jpg
# Default label 0 assigned to Snap_047.jpg
# Default label 0 assigned to Snap_094 - Copy.jpg
# Default label 0 assigned to Snap_0s05.jpg
# Default label 0 assigned to Snap_012 (4).jpg
# Default label 0 assigned to Snap_066 (3).jpg
# Default label 0 assigned to Snap_045 (3).jpg
# Default label 0 assigned to Snap_046 - Copy.jpg
# Default label 0 assigned to Snap_105 - Copy.jpg
# Default label 0 assigned to Snap_069.jpg
# Default label 0 assigned to Sn1ap_024 (15).jpg
# Default label 0 assigned to Snap_083.jpg
# Default label 0 assigned to Snap_027 - Copy.jpg
# Default label 0 assigned to Sap_148 (149).jpg
# Default label 0 assigned to Snap_096 (2).jpg
# Default label 0 assigned to Snap_020.jpg
# Default label 0 assigned to Sap_013 (1).jpg
# Default label 0 assigned to Sap_148 (44).jpg
# Default label 0 assigned to Sap_148 (61).jpg
# Default label 0 assigned to Sap_148 (126).jpg
# Default label 0 assigned to Snap_055 (3).jpg
# Default label 0 assigned to Snap_060 (2).jpg
# Default label 0 assigned to Snap_034 (3).jpg
# Default label 0 assigned to Snap_014 (3).jpg
# Default label 0 assigned to Snap_011 (2).jpg
# Default label 0 assigned to Sap_148 (142).jpg
# Default label 0 assigned to Snap_050 (3).jpg
# Default label 0 assigned to Snap_028 (3).jpg
# Default label 0 assigned to Snap_090 (2).jpg
# Default label 0 assigned to Snap_071 - Copy.jpg
# Default label 0 assigned to Snap_100 (3).jpg
# Default label 0 assigned to Sap_148 (150).jpg
# Default label 0 assigned to Snap_022.jpg
# Default label 0 assigned to Snap_049 - Copy.jpg
# Default label 0 assigned to Snap_102 (2).jpg
# Default label 0 assigned to Snap_102.jpg
# Default label 0 assigned to Sap_148 (151).jpg
# Default label 0 assigned to Sn1ap_024 (21).jpg
# Default label 0 assigned to Snap_028 (2).jpg
# Default label 0 assigned to Sap_148 (12).jpg
# Default label 0 assigned to Snap_075 (2).jpg
# Default label 0 assigned to Sn1ap_024 (12).jpg
# Default label 0 assigned to Sap_148 (53).jpg
# Default label 0 assigned to Snap_00s7.jpg
# Default label 0 assigned to Snap_018 (3).jpg
# Default label 0 assigned to Sap_148 (16).jpg
# Default label 0 assigned to Snap_056.jpg
# Default label 0 assigned to Snap_095 (2).jpg
# Default label 0 assigned to Snap_006 (3).jpg
# Default label 0 assigned to Snap_067 (3).jpg
# Default label 0 assigned to Snap_046.jpg
# Default label 0 assigned to Snap_008.jpg
# Default label 0 assigned to Sap_013 (42).jpg
# Default label 0 assigned to Snap_026.jpg
# Default label 0 assigned to Sn1ap_024 (13).jpg
# Default label 0 assigned to Snap_002 - Copy.jpg
# Default label 0 assigned to Sn1ap_024 (36).jpg
# Default label 0 assigned to Sap_148 (77).jpg
# Default label 0 assigned to Snap_077 - Copy.jpg
# Default label 0 assigned to Snap_053 (3).jpg
# Default label 0 assigned to Sn1ap_024 (30).jpg
# Default label 0 assigned to Sap_148 (65).jpg
# Default label 0 assigned to Snap_033 - Copy.jpg
# Default label 0 assigned to Sn1ap_024 (40).jpg
# Default label 0 assigned to Snap_013 - Copy.jpg
# Default label 0 assigned to Snap_025 (2).jpg
# Default label 0 assigned to Snap_041 - Copy.jpg
# Default label 0 assigned to Sap_148 (14).jpg
# Default label 0 assigned to Snap_087 - Copy.jpg
# Default label 0 assigned to Sap_148 (22).jpg
# Default label 0 assigned to Sap_148 (6).jpg
# Default label 0 assigned to Sap_148 (106).jpg
# Default label 0 assigned to Sap_148 (13).jpg
# Default label 0 assigned to Sap_148 (147).jpg
# Default label 0 assigned to Snap_044 - Copy.jpg
# Default label 0 assigned to Snap_096 (3).jpg
# Default label 0 assigned to Sn1ap_024 (56).jpg
# Default label 0 assigned to Snap_038 - Copy.jpg
# Default label 0 assigned to Snap_011 (4).jpg
# Default label 0 assigned to Sap_148 (41).jpg
# Default label 0 assigned to Sap_148 (15).jpg
# Default label 0 assigned to Snap_039 - Copy.jpg
# Default label 0 assigned to Snap_024.jpg
# Default label 0 assigned to Snap_040 (3).jpg
# Default label 0 assigned to Sap_148 (133).jpg
# Default label 0 assigned to Sap_148 (29).jpg
# Default label 0 assigned to Sn1ap_024 (54).jpg
# Training images: (556, 128, 128, 3), Training labels: (556, 2)
# Testing images: (140, 128, 128, 3), Testing labels: (140, 2)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# Define CNN model
model = Sequential()

# Add layers to the model
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(2, activation='softmax'))  # Adjust number of output classes

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 29s 1s/step - accuracy: 0.8948 - loss: 0.1346 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 2/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 3/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 47s 2s/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 4/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 5/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 6/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 7/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 8/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 9/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 10/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 225ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Test Accuracy: 100.00%

# %%
import matplotlib.pyplot as plt

# Extract the training and validation accuracy from the history object
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

# Plotting the accuracy graph
plt.plot(train_accuracy, label='Training Accuracy')
plt.plot(val_accuracy, label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()

# %%
# Extract loss values
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# Plot loss vs. epochs
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Training and Validation Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import numpy as np

# Generate predictions on test data
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)

# Calculate confusion matrix
conf_matrix = confusion_matrix(np.argmax(y_test, axis=1), y_pred_classes)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Class 0', 'Class 1'], yticklabels=['Class 0', 'Class 1'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 448ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:407: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(

# %%
from sklearn.metrics import roc_curve, auc

# Compute ROC curve
fpr, tpr, _ = roc_curve(np.argmax(y_test, axis=1), y_pred[:, 1])
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_ranking.py:1180: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
